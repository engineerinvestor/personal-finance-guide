# %% [markdown]
# # A Friendly Guide to Personal Finance and Investing for Everyone
#
# Name: Engineer Investor [@egr_investor](https://x.com/egr_investor/status/1606146597238099968)
#
# Date: 09/24/2024
#
# *Important Note: These are my opinions and do not constitute financial, legal, or tax advice. Please seek guidance from a fiduciary professional if needed.*
#
# Whether you're just starting your career or approaching retirement, understanding personal finance and investing is crucial for building a secure financial future. This guide introduces you to some excellent free resources to help you get started on your journey toward financial independence.
#
# ---
#
# ## 1. Prioritize Your Spending
#
# **Resource:** [How to Prioritize Spending Your Money - Flowchart](https://www.reddit.com/r/personalfinance/comments/4gdlu9/how_to_prioritize_spending_your_money_a_flowchart/)
#
# Managing your finances begins with understanding how to allocate your money effectively. This helpful flowchart guides you through prioritizing expenses, savings, and investments. It covers essentials like emergency funds, debt repayment, and retirement savings, ensuring you build a solid financial foundation.
#
# **Additional Reading:** Explore more personal finance topics on the [Personal Finance Reddit Wiki](https://www.reddit.com/r/personalfinance/wiki/commontopics/).
#
# ---
#
# ## 2. Embrace the Bogleheads Investment Philosophy
#
# **Resource:** [Bogleheads® Investment Philosophy](https://www.bogleheads.org/wiki/Bogleheads%C2%AE_investment_philosophy)
#
# The Bogleheads community advocates for simple, low-cost investing strategies based on the principles of Vanguard's founder, John Bogle. Their philosophy emphasizes:
#
# - **Living Below Your Means:** Spend less than you earn to free up money for investing.
# - **Developing a Workable Plan:** Create a financial plan that aligns with your goals and risk tolerance.
# - **Understanding Risk:** Balance your investments between stocks and bonds to match your comfort with market fluctuations.
# - **Investing Early and Often:** Take advantage of compound interest by starting to invest as soon as possible.
# - **Keeping It Simple:** Use a few diversified index funds to build your portfolio.
# - **Minimizing Costs and Taxes:** Opt for low-cost funds and tax-efficient investment strategies.
# - **Maintaining Discipline:** Stick to your investment plan, avoid market timing, and rebalance your portfolio as needed.
#
# By following these principles, you can create a straightforward investment strategy that doesn't require constant monitoring but is designed to yield solid long-term results.
#
# ---
#
# ## 3. Learn from Ben Felix's Evidence-Based Investing Content
#
# **Resource:** [Common Sense Investing YouTube Channel](https://www.youtube.com/c/BenFelixCSI/videos)
#
# Ben Felix offers a wealth of knowledge through his YouTube channel, where he breaks down complex investing concepts into understandable, evidence-based discussions. His videos cover topics like:
#
# - Index investing
# - Asset allocation
# - Risk management
# - Behavioral finance
#
# Watching these videos can deepen your understanding of investing principles and help you make informed decisions.
#
# ---
#
# ## Bonus Resources
#
# ### **Bonus 1: The White Coat Investor**
#
# **Resource:** [White Coat Investor Blog and Podcast](https://www.whitecoatinvestor.com/classic-blog/#classics)
#
# Originally aimed at physicians, the White Coat Investor provides valuable insights for all high-income professionals. It covers topics such as:
#
# - Retirement account strategies
# - Tax optimization
# - Debt management
# - Insurance planning
#
# The practical advice offered can help you maximize your earnings and secure your financial future.
#
# ### **Bonus 2: Rational Reminder Community and Podcast**
#
# **Resource:** [Rational Reminder Community](https://community.rationalreminder.ca)
#
# Hosted by Ben Felix and Cameron Passmore, the Rational Reminder podcast and community delve into advanced investing topics, including:
#
# - Factor investing
# - Portfolio construction
# - Financial planning
# - Interviews with industry experts
#
# This resource is ideal for those looking to deepen their investing knowledge beyond the basics.
#
# ---
#
# ## Additional Tools and Tips
#
# ### **Compound Interest Calculator**
#
# Understanding compound interest is key to appreciating how your investments can grow over time.
#
# **Tool:** [Investor.gov Compound Interest Calculator](https://www.investor.gov/financial-tools-calculators/calculators/compound-interest-calculator)
#
# Use this calculator to see how regular investments can accumulate, highlighting the importance of starting early and contributing consistently.
#
# ### **Honest Math Portfolio Simulator**
#
# For a more in-depth analysis of investment scenarios, consider running simulations to project potential outcomes.
#
# **Tool:** [Honest Math Portfolio Simulator](https://www.honestmath.com/)
#
# This tool allows you to perform Monte Carlo simulations, helping you understand the range of possible returns and risks associated with different investment strategies.
#
# ---
#
# ## Simple Investing Mantras for Beginners
#
# - **Start Early:** Time is one of the most powerful tools in investing due to compound growth.
# - **Spend Less Than You Earn:** Free up funds for investing by cutting unnecessary expenses.
# - **Diversify Your Portfolio:** Spread investments across various asset classes to manage risk.
# - **Avoid Market Timing:** Predicting market movements is extremely difficult; focus on long-term investing.
# - **Stay the Course:** Stick with your investment plan, even during market volatility.
# - **Don't Chase Fads:** Invest based on sound principles, not on envy or fear of missing out.
#
# Remember, investing is a marathon, not a sprint. Discipline and adherence to proven strategies are key to achieving your financial goals.
#
# ---
#
# ## Dive Deeper with Financial Analysis Using Python
#
# For those interested in the technical side of finance, learning how to analyze financial data can be incredibly rewarding.
#
# **Resource:** [Engineer Investor GitHub Repository](https://github.com/engineerinvestor/Finance-Education)
#
# This repository offers tutorials on performing financial and stock market analysis using Python. The first tutorial covers computing the Sharpe ratio of a stock or fund, which measures risk-adjusted returns.
#
# - **Access the Tutorial:** [Computing Sharpe Ratio with Python](https://github.com/engineerinvestor/Finance-Education/blob/main/Computing_Sharpe_Ratio_of_a_Stock_Using_T_Bill_Return_Data_with_Python.ipynb)
# - **Run on Google Colab:** Easily run and modify the code without installing anything on your computer.
#
# Engaging with these resources can enhance your analytical skills and provide a deeper understanding of investment performance metrics.
#
# ---
#
# ## Conclusion
#
# Embarking on your personal finance and investing journey is an important step toward financial independence and freedom. By utilizing these resources and adhering to timeless investing principles, you can build a solid foundation for your financial future.
#
# **Key Takeaways:**
#
# - **Educate Yourself:** Use the provided resources to increase your financial literacy.
# - **Develop a Plan:** Create an investment policy that aligns with your goals and risk tolerance.
# - **Be Consistent:** Regularly contribute to your investments and stick to your strategy.
# - **Stay Informed:** Keep learning and stay engaged with reputable financial communities.
#
# Good luck on your investing journey!
#
# ---
#
# *Feedback and recommendations are always welcome as you navigate the world of personal finance and investing.*

# %% [markdown]
# # Appendix: My Personal Investing Policy Statement
#
# **Investment Philosophy**
#
# I adhere to the Bogleheads® investment philosophy, emphasizing low-cost, passive investing strategies. My approach focuses on aligning the duration of assets with the expected timing of liabilities (asset-liability matching) to ensure financial stability over time.
#
# ---
#
# **Target Asset Allocation**
#
# - **Overall Allocation**: **90–95% Stocks** / **5–10% Bonds**
#   - Mirrors the glide path of Vanguard/Fidelity target-date index funds, using **Vanguard Target Retirement 2055 Fund (VFFVX)** as a reference.
#
# ---
#
# **Equities Allocation**
#
# - **Market Exposure**:
#   - **60% U.S. Stocks**
#   - **40% International Stocks**
#     - Follows the global market capitalization split similar to **VT**.
# - **Equity Strategy**:
#   - Aim for exposure combining **60% Market Beta (VT)** and **40% Global Value Tilt (AVGV)**.
# - **Investment Vehicles**:
#   - **Market Beta**:
#     - U.S.: **VTI** / **ITOT**
#     - International: **VXUS** / **IXUS**
#   - **Value Tilt**:
#     - Avantis and DFA ETFs: **AVGV**, **AVUV** / **DFSV**, **AVDV** / **DISV**, **AVES**
# - **Simplified Option**:
#   - Use **VFFVX** in tax-advantaged accounts.
#   - Use **VTI** and **VXUS** in taxable accounts if complexity arises.
#
# ---
#
# **Bonds Allocation**
#
# - **Tax-Advantaged Accounts**: Use **BND** (Vanguard Total Bond Market ETF).
# - **Taxable Accounts**: Use **MUB** (iShares National Muni Bond ETF).
# - **Short-Term Liabilities (<1 year)**: Use **SGOV** (iShares 0-3 Month Treasury Bond ETF).
#
# ---
#
# **Cash and Emergency Funds**
#
# - **Emergency Fund**: Maintain ~12 months of expenses in cash-like assets.
# - **Primary Bank Account**: Keep ~1 month of expenses.
# - **Cash Allocation**:
#   - High-Yield Savings Accounts (e.g., **Marcus HYSA**)
#   - Treasury Bills (**SGOV**)
#   - Money Market Funds (**VMFXX**)
#   - I Bonds
#   - Box Spreads (**BOXX**)
# - **Taxable Accounts**:
#   - Use municipal bonds (**MUB** / **SUB**) and municipal money market funds (**VMSXX**) when tax-adjusted yields are favorable.
#
# ---
#
# **Contribution Strategy**
#
# - **Maximize Tax-Advantaged Accounts Annually**:
#   - **Backdoor Roth IRA** (file **Form 8606** with taxes)
#   - **Traditional 401(k)**
#   - **Mega Backdoor Roth 401(k)**
#   - **Health Savings Account (HSA)**
#   - **529 College Savings Plan** (Utah)
#
# ---
#
# **Asset Location and Tax Efficiency**
#
# - **Roth Accounts**:
#   - Place high-expected-return assets like small-cap value stocks.
# - **Non-Roth Tax-Advantaged Accounts**:
#   - Hold bonds and income-generating assets.
# - **Taxable Accounts**:
#   - Invest in tax-efficient funds, such as **VTI** / **ITOT** and **VXUS** / **IXUS** or **AVGV** only.
#   - Prefer international stocks to leverage the foreign dividend tax credit.
# - **Tax-Loss Harvesting**:
#   - Implement during significant market downturns to offset capital gains.
#
# ---
#
# **Health Savings Account (HSA)**
#
# - **Expense Tracking**:
#   - Save all substantial medical receipts as PDFs for future reimbursement claims.
#
# ---
#
# **Rebalancing and Maintenance**
#
# - **Periodic Review**:
#   - Monitor asset allocation and rebalance as needed to maintain target percentages.
# - **Tax Considerations**:
#   - Be mindful of tax implications when rebalancing, prioritizing tax-efficient strategies.
#
# ---
#
# **Additional Notes**
#
# - **Tax Efficiency**:
#   - Prioritize investments and asset locations that minimize tax liabilities.
# - **Simplicity and Cost-Effectiveness**:
#   - Keep the investment portfolio straightforward and minimize fees.
# - **Long-Term Focus**:
#   - Align investments with long-term financial goals and risk tolerance.
# - **Record-Keeping**:
#   - Maintain thorough documentation for all investment activities and tax-related actions.
#
# ---
#
# By adhering to this policy statement, I aim to achieve a balanced, efficient, and goal-oriented investment portfolio that supports my financial objectives now and in the future.

# %% [markdown]
# ---
#
# ### *Legal Disclaimer*
#
# **Informational Purposes Only**
#
# The information provided in this guide is for general informational and educational purposes only. It is not intended as, and should not be construed as, financial, investment, legal, or professional advice. The content is based on personal opinions and experiences and does not take into account your individual objectives, financial situation, or needs.
#
# **No Professional Advice**
#
# You should not rely solely on the information in this guide for making financial decisions. Before making any investment or financial decisions, consider consulting with a qualified financial advisor, accountant, or other professional who can provide guidance tailored to your specific circumstances.
#
# **No Warranties**
#
# While every effort has been made to ensure the accuracy and completeness of the information presented, no guarantee is given regarding the reliability, completeness, or suitability of the content. All information is provided "as is" without warranty of any kind, express or implied.
#
# **Limitation of Liability**
#
# Under no circumstances shall the author or any affiliated parties be liable for any direct, indirect, incidental, special, consequential, or punitive damages arising out of your access to or use of this guide. This includes, but is not limited to, any financial losses or damages resulting from investment decisions made based on the information provided.
#
# **External Links**
#
# This guide contains links to external websites for additional information and resources. These links are provided for convenience and do not constitute an endorsement of any products, services, or opinions expressed on those websites. We have no control over the content of external sites and accept no responsibility for them.
#
# **Investment Risks**
#
# All investments carry risks, including the possible loss of principal. Past performance is not indicative of future results. The value of investments can go down as well as up, and you may not get back the amount you originally invested.
#
# **No Endorsement**
#
# Reference to any specific product, service, or entity does not constitute an endorsement or recommendation. Any mention of third-party products or services is for informational purposes only.
#
# **Personal Responsibility**
#
# You acknowledge that any reliance on the information provided in this guide is at your own risk. You are solely responsible for your own investment and financial decisions.
#
# **Changes to Content**
#
# The content of this guide may be updated or changed without notice at any time. There is no obligation to update any information to reflect changes in circumstances or market conditions.
#
# ---
